# %% [markdown]
# # **Tap into important details of a Crew Run - Task Output, Usage Metrics - Token Usage, Tool Failures**

# %% [markdown]
# # Install Libraries

# %%
# !pip install -q crewai crewai_tools
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.8/189.8 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.8/820.8 kB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 72.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.5/252.5 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.6/222.6 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 81.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.6/463.6 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 60.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.6/803.6 kB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.2/485.2 kB 27.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.3/591.3 kB 31.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.9/353.9 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.6/405.6 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.9/348.9 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 81.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 73.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.4/731.4 kB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.5/310.5 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 20.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# bigframes 2.42.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.

# %% [markdown]
# # Version Check
#
# After successful installation....

# %%
import crewai
import crewai_tools
print(crewai.__version__)
print(crewai_tools.__version__)
# Out:
# 1.15.10
# 1.15.10

# %% [markdown]
# # Set API Keys for LLMs & Tools

# %%
from google.colab import userdata
import os
os.environ["SERPER_API_KEY"] = userdata.get('SERPER_API_KEY')
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_API_KEY_NEW')
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %% [markdown]
# # Import necessary classes/methods from the package

# %%
from crewai import Agent, Task, Crew, LLM
from crewai_tools import SerperDevTool

# %% [markdown]
# # Define the LLM Object

# %%
# Create an LLM with a temperature of 0 to ensure deterministic outputs from the LLM
# Set temperature to higher values for creative outputs from the LLM

# OPENAI LLMs
# llm = LLM(
#          # model="gpt-5.4-mini",
#           model="gpt-5.4-nano",
#           base_url="https://api.openai.com/v1",
#           api_key = os.environ["OPENAI_API_KEY"],
#           temperature=0.7)


# GROQ hosted LLMs
llm = LLM(
     model="llama-3.3-70b-versatile",
     base_url="https://api.groq.com/openai/v1",
     api_key=os.environ["GROQ_API_KEY"],
     temperature=0.7)

# %% [markdown]
# # Instantiate Tools

# %%
# Create tools
search_tool = SerperDevTool()

# %% [markdown]
# # Define Agents

# %%
researcher = Agent(
    role="Technology Researcher",
    goal="""Research the latest developments in {topic}""",
    backstory="""You are an experienced researcher known for thorough technical research and enlightning summary of the main technical points for a gven {topic}.""",
    llm=llm,
    tools=[search_tool],
    verbose=True
)

# %% [markdown]
# # Define Tasks

# %%
task = Task(
  description="""Find suitable information about {topic}""",
  expected_output="Good technical summary with insights as bullet points, followed by a summary.",
  agent = researcher
)

# %% [markdown]
# # Define the Crew (Orchestration Layer)

# %%
crew = Crew(
  agents=[researcher],
  tasks=[task],
  verbose=True
)

# %% [markdown]
# # Run the Crew

# %%
results = await crew.kickoff_async(
                                    inputs={"topic": "Groq LPU"}
                                    )

print(results)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 24c272e5-7437-42b0-9a91-4800f25d5273                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find suitable information about Groq LPU                                                                 │
# │  ID: 87bfefce-2680-4043-919e-a1fcb1fd5bb5                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher                                                                                   │
# │                                                                                                                 │
# │  Task: Find suitable information about Groq LPU                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU latest developments"}</function>'}}
# ERROR:root:OpenAI API call failed: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU latest developments"}</function>'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: OpenAI API call failed: Error code: 400 - {'error': {'message': "Failed to call a function. Please      │
# │  adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code':       │
# │  'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU   │
# │  latest developments"}</function>'}}                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# [CrewAIEventsBus] Warning: Event pairing mismatch. 'llm_call_failed' closed 'flow_started' (expected
# 'llm_call_started')
# ERROR:crewai.flow.runtime:Error executing listener call_llm_native_tools: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU latest developments"}</function>'}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU latest developments"}</function>'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: OpenAI API call failed: Error code: 400 - {'error': {'message': "Failed to call a function. Please      │
# │  adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code':       │
# │  'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU   │
# │  latest developments"}</function>'}}                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: Error code: 400 - {'error': {'message': "Failed to call a function. Please adjust your prompt. See 'failed_generation' for more details.", 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '<function=search_the_internet_with_serper{"search_query": "Groq LPU latest developments"}</function>'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher                                                                                   │
# │                                                                                                                 │
# │  Task: Find suitable information about Groq LPU                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Args: {'search_query': 'Groq LPU latest developments'}                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_the_internet_with_serper executed with result: {'searchParameters': {'q': 'Groq LPU latest developments', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Groq is the premier neocloud for fast inference', 'link': 'https://g...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Output: {'searchParameters': {'q': 'Groq LPU latest developments', 'type': 'search', 'num': 10, 'engine':      │
# │  'google'}, 'organic': [{'title': 'Groq is the premier neocloud for fast inference', 'link':                    │
# │  'https://groq.com/', 'snippet': 'Groq pioneered the LPU in 2016, the first chip purpose-built for inference.   │
# │  Every design choice focuses on keeping intelligence fast and affordable.', 'position': 1}, {'title': 'LPU |    │
# │  Groq is the premier neocloud for fast inference', 'link': 'https://groq.com/lpu-architecture', 'snippet':      │
# │  "Learn More Aug 01, 2025 Inside the LPU: Deconstructing Groq's Speed May 27, 2025. Is Optimized for MoE &      │
# │  Other Large Models Mar 07, 2025. Fuel for Developers ...", 'position': 2}, {'title': 'Inside NVIDIA Groq 3     │
# │  LPX: The Low-Latency Inference Accelerator for ...', 'link':                                                   │
# │  'https://developer.nvidia.com/blog/inside-nvidia-groq-3-lpx-the-low-latency-inference-accelerator-for-the-nvi  │
# │  dia-vera-rubin-platform/', 'snippet': 'NVIDIA Groq 3 LPX is a new rack-scale inference accelerator for the     │
# │  NVIDIA Vera Rubin platform, designed for the low-latency and large-context ...', 'position': 3}, {'title':     │
# │  'Blog | Groq is the premier neocloud for fast inference', 'link': 'https://groq.com/blog', 'snippet':          │
# │  'Expanding to Meet Demand Dec 01, 2025 Groq Recognized in 2025 Gartner®. Introducing MCP Connectors in Beta    │
# │  on GroqCloud Oct 29, 2025 Day Zero Support for ...', 'position': 4}, {'title': 'How the hell is Groq raising   │
# │  more money?', 'link': 'https://www.zach.be/p/how-the-hell-is-groq-raising-more', 'snippet': 'Groq, the AI      │
# │  chip company company that was acquired by Nvidia in December of last year, is raising $650M. Groq has four     │
# │  large datacenter ...', 'position': 5}, {'title': 'Groq CEO sees GPU and LPU as complementary as AI compute     │
# │  ...', 'link': 'https://www.digitimes.com/news/a20260622PD220/groq-gpu-nvidia-demand.html', 'snippet': "Groq    │
# │  CEO sees GPU and LPU as complementary as AI compute demand grows. Nvidia's planned US$20 billion strategic     │
# │  deal with Groq is built on a ...", 'position': 6}, {'title': 'Deep Dive into NVIDIA Groq 3 LPU: A New Choice   │
# │  for AI Inference', 'link':                                                                                     │
# │  'https://naddod.medium.com/deep-dive-into-nvidia-groq-3-lpu-a-new-choice-for-ai-inference-76eaea45bedf',       │
# │  'snippet': 'The Groq 3 LPU has been integrated into the next-generation Vera Rubin platform, working           │
# │  alongside GPUs to form an inference acceleration ...', 'position': 7}, {'title': 'LPU Unleashed: How Groq is   │
# │  Rewriting AI Inference', 'link':                                                                               │
# │  'https://www.baytechconsulting.com/blog/lpu-unleashed-groq-rewriting-ai-inference', 'snippet': "One of the     │
# │  most consequential developments in the 2026 AI ecosystem is Groq's deep integration of OpenAI's newest         │
# │  open-weight models, ...", 'position': 8}, {'title': 'NVIDIA Introducing GROQ 3 LPU AI Just Became Instant',    │
# │  'link': 'https://www.youtube.com/watch?v=yV41-q94D64', 'snippet': '... new challenger is changing everything.  │
# │  Groq has introduced the LPU (Language Processing Unit) — a completely new kind of AI chip designed\xa0...',    │
# │  'position': 9}], 'peopleAlsoAsk': [{'question': 'Is Groq getting acquired?', 'snippet': '', 'title': '',       │
# │  'link': ''}, {'question': 'What is the latest Groq model?', 'snippet': '', 'title': '', 'link': ''},           │
# │  {'question': 'Does Groq use lpu?', 'snippet': 'So Groq built the LPU. Its four core design principles deliver  │
# │  performance advantages today and tomorrow. These include: Software-first.Mar 7, 2025', 'title': '', 'link':    │
# │  ''}, {'question': 'Does Groq compete with Broadcom?', 'snippet': "Groq's relationship to Broadcom is           │
# │  complex—while they don't directly compete on the same product, Broadcom's actions (such as enabling a custom   │
# │  chip for a major player) can affect the overall market. Additionally, Broadcom's networking solutions can      │
# │  complement chips like Groq's by scaling out systems.Feb 13, 2025", 'title': '', 'link': ''}],                  │
# │  'relatedSearches': [{'query': 'Groq LPU price'}, {'query': 'Groq LPU v2'}, {'query': 'Groq LPU buy'},          │
# │  {'query': 'Groq models'}, {'query': 'Groq LPU architecture'}, {'query': 'Groq LPU specs'}], 'credits': 1}      │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Technology Researcher                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are the key points about the latest developments in Groq LPU:                                             │
# │  * Groq pioneered the LPU in 2016, the first chip purpose-built for inference, with a design focus on keeping   │
# │  intelligence fast and affordable.                                                                              │
# │  * The LPU has four core design principles that deliver performance advantages, including a software-first      │
# │  approach.                                                                                                      │
# │  * Groq has introduced the LPU (Language Processing Unit), a new kind of AI chip designed for low-latency and   │
# │  large-context inference acceleration.                                                                          │
# │  * The Groq 3 LPU has been integrated into the next-generation Vera Rubin platform, working alongside GPUs to   │
# │  form an inference acceleration platform.                                                                       │
# │  * Groq's LPU is seen as complementary to GPUs, with the CEO stating that they can work together to meet        │
# │  growing AI compute demand.                                                                                     │
# │  * The LPU has been optimized for large models, including OpenAI's newest open-weight models.                   │
# │  * Groq has been recognized in the 2025 Gartner report and has expanded to meet growing demand.                 │
# │  * The company has also introduced MCP Connectors in beta on GroqCloud and has announced Day Zero Support for   │
# │  new models.                                                                                                    │
# │                                                                                                                 │
# │  In summary, Groq's LPU is a purpose-built chip for inference acceleration, with a focus on low-latency and     │
# │  large-context processing. The company has made significant developments in its LPU technology, including       │
# │  integration with the Vera Rubin platform and optimization for large models. Groq's LPU is seen as              │
# │  complementary to GPUs, and the company has been recognized for its innovations in the field. With its          │
# │  expanding capabilities and growing demand, Groq is poised to play a significant role in the development of AI  │
# │  inference technology.                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find suitable information about Groq LPU                                                                 │
# │  Agent: Technology Researcher                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Here are the key points about the latest developments in Groq LPU:
# * Groq pioneered the LPU in 2016, the first chip purpose-built for inference, with a design focus on keeping intelligence fast and affordable.
# * The LPU has four core design principles that deliver performance advantages, including a software-first approach.
# * Groq has introduced the LPU (Language Processing Unit), a new kind of AI chip designed for low-latency and large-context inference acceleration.
# * The Groq 3 LPU has been integrated into the next-generation Vera Rubin platform, working alongside GPUs to form an inference acceleration platform.
# * Groq's LPU is seen as complementary to GPUs, with the CEO stating that they can work together to meet growing AI compute demand.
# * The LPU has been optimized for large models, including OpenAI's newest open-weight models.
# * Groq has been recognized in the 2025 Gartner report and has expanded to meet growing demand.
# * The company has also introduced MCP Connectors in beta on GroqCloud and has announced Day Zero Support for new models.
#
# In summary, Groq's LPU is a purpose-built chip for inference acceleration, with a focus on low-latency and large-context processing. The company has made significant developments in its LPU technology, including integration with the Vera Rubin platform and optimization for large models. Groq's LPU is seen as complementary to GPUs, and the company has been recognized for its innovations in the field. With its expanding capabilities and growing demand, Groq is poised to play a significant role in the development of AI inference technology.
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 24c272e5-7437-42b0-9a91-4800f25d5273                                                                       │
# │  Final Output: Here are the key points about the latest developments in Groq LPU:                               │
# │  * Groq pioneered the LPU in 2016, the first chip purpose-built for inference, with a design focus on keeping   │
# │  intelligence fast and affordable.                                                                              │
# │  * The LPU has four core design principles that deliver performance advantages, including a software-first      │
# │  approach.                                                                                                      │
# │  * Groq has introduced the LPU (Language Processing Unit), a new kind of AI chip designed for low-latency and   │
# │  large-context inference acceleration.                                                                          │
# │  * The Groq 3 LPU has been integrated into the next-generation Vera Rubin platform, working alongside GPUs to   │
# │  form an inference acceleration platform.                                                                       │
# │  * Groq's LPU is seen as complementary to GPUs, with the CEO stating that they can work together to meet        │
# │  growing AI compute demand.                                                                                     │
# │  * The LPU has been optimized for large models, including OpenAI's newest open-weight models.                   │
# │  * Groq has been recognized in the 2025 Gartner report and has expanded to meet growing demand.                 │
# │  * The company has also introduced MCP Connectors in beta on GroqCloud and has announced Day Zero Support for   │
# │  new models.                                                                                                    │
# │                                                                                                                 │
# │  In summary, Groq's LPU is a purpose-built chip for inference acceleration, with a focus on low-latency and     │
# │  large-context processing. The company has made significant developments in its LPU technology, including       │
# │  integration with the Vera Rubin platform and optimization for large models. Groq's LPU is seen as              │
# │  complementary to GPUs, and the company has been recognized for its innovations in the field. With its          │
# │  expanding capabilities and growing demand, Groq is poised to play a significant role in the development of AI  │
# │  inference technology.                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
type(results)
# Out:
# ╭────────────────────────── Tracing Preference Saved ──────────────────────────╮
# │                                                                              │
# │  Info: Tracing has been disabled.                                            │
# │                                                                              │
# │  Your preference has been saved. Future Crew/Flow executions will not        │
# │  collect traces.                                                             │
# │                                                                              │
# │  To enable tracing later, do any one of these:                               │
# │  • Set tracing=True in your Crew/Flow code                                   │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file               │
# │  • Run: crewai traces enable                                                 │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# crewai.crews.crew_output.CrewOutput

# %%
dir(results)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__class_vars__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__fields__',
#  '__fields_set__',
#  '__format__',
#  '__ge__',
#  '__get_pydantic_core_schema__',
#  '__get_pydantic_json_schema__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pretty__',
#  '__private_attributes__',
#  '__pydantic_complete__',
#  '__pydantic_computed_fields__',
#  '__pydantic_core_schema__',
#  '__pydantic_custom_init__',
#  '__pydantic_decorators__',
#  '__pydantic_extra__',
#  '__pydantic_fields__',
#  '__pydantic_fields_set__',
#  '__pydantic_generic_metadata__',
#  '__pydantic_init_subclass__',
#  '__pydantic_on_complete__',
#  '__pydantic_parent_namespace__',
#  '__pydantic_post_init__',
#  '__pydantic_private__',
#  '__pydantic_root_model__',
#  '__pydantic_serializer__',
#  '__pydantic_setattr_handlers__',
#  '__pydantic_validator__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__replace__',
#  '__repr__',
#  '__repr_args__',
#  '__repr_name__',
#  '__repr_recursion__',
#  '__repr_str__',
#  '__rich_repr__',
#  '__setattr__',
#  '__setstate__',
#  '__signature__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_calculate_keys',
#  '_copy_and_set_values',
#  '_get_value',
#  '_iter',
#  '_setattr_handler',
#  'construct',
#  'copy',
#  'dict',
#  'from_orm',
#  'has_tool_failures',
#  'json',
#  'json_dict',
#  'model_computed_fields',
#  'model_config',
#  'model_construct',
#  'model_copy',
#  'model_dump',
#  'model_dump_json',
#  'model_extra',
#  'model_fields',
#  'model_fields_set',
#  'model_json_schema',
#  'model_parametrized_name',
#  'model_post_init',
#  'model_rebuild',
#  'model_validate',
#  'model_validate_json',
#  'model_validate_strings',
#  'parse_file',
#  'parse_obj',
#  'parse_raw',
#  'pydantic',
#  'raw',
#  'schema',
#  'schema_json',
#  'tasks_output',
#  'to_dict',
#  'token_usage',
#  'tool_failures',
#  'update_forward_refs',
#  'usage_metrics',
#  'validate']

# %%
for name in dir(results):
    try:
        value = getattr(results, name)

        if callable(value):
            print(f"METHOD    {name}")
        else:
            print(f"ATTRIBUTE {name}")

    except Exception as e:
        print(f"SKIPPED {name}: {type(e).__name__}")
# Out:
# ATTRIBUTE __abstractmethods__
# ATTRIBUTE __annotations__
# METHOD    __class__
# METHOD    __class_getitem__
# ATTRIBUTE __class_vars__
# METHOD    __copy__
# METHOD    __deepcopy__
# METHOD    __delattr__
# ATTRIBUTE __dict__
# METHOD    __dir__
# ATTRIBUTE __doc__
# METHOD    __eq__
# ATTRIBUTE __fields__
# ATTRIBUTE __fields_set__
# METHOD    __format__
# METHOD    __ge__
# METHOD    __get_pydantic_core_schema__
# METHOD    __get_pydantic_json_schema__
# METHOD    __getattr__
# METHOD    __getattribute__
# METHOD    __getitem__
# METHOD    __getstate__
# METHOD    __gt__
# ATTRIBUTE __hash__
# METHOD    __init__
# METHOD    __init_subclass__
# METHOD    __iter__
# METHOD    __le__
# METHOD    __lt__
# ATTRIBUTE __module__
# METHOD    __ne__
# METHOD    __new__
# METHOD    __pretty__
# ATTRIBUTE __private_attributes__
# ATTRIBUTE __pydantic_complete__
# ATTRIBUTE __pydantic_computed_fields__
# ATTRIBUTE __pydantic_core_schema__
# ATTRIBUTE __pydantic_custom_init__
# ATTRIBUTE __pydantic_decorators__
# ATTRIBUTE __pydantic_extra__
# ATTRIBUTE __pydantic_fields__
# ATTRIBUTE __pydantic_fields_set__
# ATTRIBUTE __pydantic_generic_metadata__
# METHOD    __pydantic_init_subclass__
# METHOD    __pydantic_on_complete__
# ATTRIBUTE __pydantic_parent_namespace__
# ATTRIBUTE __pydantic_post_init__
# ATTRIBUTE __pydantic_private__
# ATTRIBUTE __pydantic_root_model__
# ATTRIBUTE __pydantic_serializer__
# ATTRIBUTE __pydantic_setattr_handlers__
# ATTRIBUTE __pydantic_validator__
# METHOD    __reduce__
# METHOD    __reduce_ex__
# METHOD    __replace__
# METHOD    __repr__
# METHOD    __repr_args__
# METHOD    __repr_name__
# METHOD    __repr_recursion__
# METHOD    __repr_str__
# METHOD    __rich_repr__
# METHOD    __setattr__
# METHOD    __setstate__
# SKIPPED __signature__: AttributeError
# METHOD    __sizeof__
# ATTRIBUTE __slots__
# METHOD    __str__
# METHOD    __subclasshook__
# ATTRIBUTE __weakref__
# ATTRIBUTE _abc_impl
# METHOD    _calculate_keys
# METHOD    _copy_and_set_values
# METHOD    _get_value
# METHOD    _iter
# METHOD    _setattr_handler
# METHOD    construct
# METHOD    copy
# METHOD    dict
# METHOD    from_orm
# ATTRIBUTE has_tool_failures
# SKIPPED json: ValueError
# ATTRIBUTE json_dict
# ATTRIBUTE model_computed_fields
# ATTRIBUTE model_config
# METHOD    model_construct
# METHOD    model_copy
# METHOD    model_dump
# METHOD    model_dump_json
# ATTRIBUTE model_extra
# ATTRIBUTE model_fields
# ATTRIBUTE model_fields_set
# METHOD    model_json_schema
# METHOD    model_parametrized_name
# METHOD    model_post_init
# METHOD    model_rebuild
# METHOD    model_validate
# METHOD    model_validate_json
# METHOD    model_validate_strings
# METHOD    parse_file
# METHOD    parse_obj
# METHOD    parse_raw
# ATTRIBUTE pydantic
# ATTRIBUTE raw
# METHOD    schema
# METHOD    schema_json
# ATTRIBUTE tasks_output
# METHOD    to_dict
# ATTRIBUTE token_usage
# ATTRIBUTE tool_failures
# METHOD    update_forward_refs
# ATTRIBUTE usage_metrics
# METHOD    validate

# %%
att_list = [
    "tasks_output",
    "token_usage",
    "tool_failures",
    "usage_metrics"
]

for att in att_list:
    print(f"{att}:")
    print(getattr(results, att))
    print("-" * 50)
# Out:
# tasks_output:
# [TaskOutput(description='Find suitable information about Groq LPU', name='Find suitable information about Groq LPU', expected_output='Good technical summary with insights as bullet points, followed by a summary.', summary='Find suitable information about Groq LPU...', raw="Here are the key points about the latest developments in Groq LPU:\n* Groq pioneered the LPU in 2016, the first chip purpose-built for inference, with a design focus on keeping intelligence fast and affordable.\n* The LPU has four core design principles that deliver performance advantages, including a software-first approach.\n* Groq has introduced the LPU (Language Processing Unit), a new kind of AI chip designed for low-latency and large-context inference acceleration.\n* The Groq 3 LPU has been integrated into the next-generation Vera Rubin platform, working alongside GPUs to form an inference acceleration platform.\n* Groq's LPU is seen as complementary to GPUs, with the CEO stating that they can work together to meet growing AI compute demand.\n* The LPU has been optimized for large models, including OpenAI's newest open-weight models.\n* Groq has been recognized in the 2025 Gartner report and has expanded to meet growing demand.\n* The company has also introduced MCP Connectors in beta on GroqCloud and has announced Day Zero Support for new models.\n\nIn summary, Groq's LPU is a purpose-built chip for inference acceleration, with a focus on low-latency and large-context processing. The company has made significant developments in its LPU technology, including integration with the Vera Rubin platform and optimization for large models. Groq's LPU is seen as complementary to GPUs, and the company has been recognized for its innovations in the field. With its expanding capabilities and growing demand, Groq is poised to play a significant role in the development of AI inference technology.", pydantic=None, json_dict=None, agent='Technology Researcher', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are Technology Researcher. You are an experienced researcher known for thorough technical research and enlightning summary of the main technical points for a gven Groq LPU.\nYour personal goal is: Research the latest developments in Groq LPU'}, {'role': 'user', 'content': '\nCurrent Task: Find suitable information about Groq LPU\n\nThis is the expected criteria for your final answer: Good technical summary with insights as bullet points, followed by a summary.\nyou MUST return the actual complete content as the final answer, not a summary.'}, {'role': 'assistant', 'content': '', 'tool_calls': [{'id': '35hgvav2h', 'type': 'function', 'function': {'name': 'search_the_internet_with_serper', 'arguments': '{"search_query":"Groq LPU latest developments"}'}}]}, {'role': 'tool', 'content': '{\'searchParameters\': {\'q\': \'Groq LPU latest developments\', \'type\': \'search\', \'num\': 10, \'engine\': \'google\'}, \'organic\': [{\'title\': \'Groq is the premier neocloud for fast inference\', \'link\': \'https://groq.com/\', \'snippet\': \'Groq pioneered the LPU in 2016, the first chip purpose-built for inference. Every design choice focuses on keeping intelligence fast and affordable.\', \'position\': 1}, {\'title\': \'LPU | Groq is the premier neocloud for fast inference\', \'link\': \'https://groq.com/lpu-architecture\', \'snippet\': "Learn More Aug 01, 2025 Inside the LPU: Deconstructing Groq\'s Speed May 27, 2025. Is Optimized for MoE & Other Large Models Mar 07, 2025. Fuel for Developers ...", \'position\': 2}, {\'title\': \'Inside NVIDIA Groq 3 LPX: The Low-Latency Inference Accelerator for ...\', \'link\': \'https://developer.nvidia.com/blog/inside-nvidia-groq-3-lpx-the-low-latency-inference-accelerator-for-the-nvidia-vera-rubin-platform/\', \'snippet\': \'NVIDIA Groq 3 LPX is a new rack-scale inference accelerator for the NVIDIA Vera Rubin platform, designed for the low-latency and large-context ...\', \'position\': 3}, {\'ti ...
# --------------------------------------------------
# token_usage:
# total_tokens=2274 prompt_tokens=1923 cached_prompt_tokens=0 completion_tokens=351 reasoning_tokens=0 cache_creation_tokens=0 successful_requests=2
# --------------------------------------------------
# tool_failures:
# []
# --------------------------------------------------
# usage_metrics:
# {'total_tokens': 2274, 'prompt_tokens': 1923, 'cached_prompt_tokens': 0, 'completion_tokens': 351, 'reasoning_tokens': 0, 'cache_creation_tokens': 0, 'successful_requests': 2}
# --------------------------------------------------
